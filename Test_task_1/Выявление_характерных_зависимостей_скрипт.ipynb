# %%
# %run тестовое_задание_WiseTech_для_скрипта.py
# Out:
# <font face='liberation serif' size=6 color='darkblue'>Определение характерных параметров для анализа торговли финансовыми инструментами</font>
# <font face='liberation serif' size=4 color='darkblue'>1. Общее описание задачи:<br></font>
# <font face='liberation serif' size=3 color='darkblue'>- быстро и грубо оценить влияние каждого параметра на результаты
#
# <br>- выбрать 5-6 строчек с наиболее характерными параметрами и целесообразными результатами<br>Цель:<br>отобрать строки с наиболее характерными параметрами и целесообразными результатами для более детального дальнейшего анализа</font>
# <font face='liberation serif' size=4 color='darkblue'>2. Импортируем библиотеки</font>
# <font face='liberation serif' size=4 color='darkblue'>3. Создаем функции</font>
# <font face='liberation serif' size=4 color='darkblue'>4. Загружаем данные</font>
# <font face='liberation serif' size=4 color='darkblue'>5. Оцениваем влияние параметров на результаты</font>
# None
# ...
